# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/My Drive/Fall 2020/1006 Capstone/NYU_Team18_Accern_Capstone_Fall2020/'
# Out:
# /content/drive/My Drive/Fall 2020/1006 Capstone/NYU_Team18_Accern_Capstone_Fall2020

# %%
# !pip install transformers
# !pip install pytorch-lightning==1.0.8
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/ed/db/98c3ea1a78190dac41c0127a063abf92bd01b4b0b6970a6db1c2f5b66fa0/transformers-4.0.1-py3-none-any.whl (1.4MB)
#      |████████████████████████████████| 1.4MB 21.9MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers==0.9.4
#   Downloading https://files.pythonhosted.org/packages/0f/1c/e789a8b12e28be5bc1ce2156cf87cb522b379be9cadc7ad8091a4cc107c4/tokenizers-0.9.4-cp36-cp36m-manylinux2010_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 53.5MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.7)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 46.2MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.17.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=8ae71bf31964df55d5cbec4c298f03ab59e2c8e005e5635964cfdd28a020af8d
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.9.4 transformers-4.0.1
# Collecting pytorch-lightning==1.0.8
#   Downloading https://files.pythonhosted.org/packages/2e/92/078c5524c875c274ded8a0317ef31a2bb86d02c5c74089ab754d0f12b29c/pytorch_lightning-1.0.8-py3-none-any.whl (561kB)
#      |████████████████████████████████| 563kB 17.1MB/s
# Collecting PyYAML>=5.1
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
#      |████████████████████████████████| 276kB 54.0MB/s
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.6/dist-packages (from pytorch-lightning==1.0.8) (1.7.0+cu101)
# Collecting fsspec>=0.8.0
#   Downloading https://files.pythonhosted.org/packages/a5/8b/1df260f860f17cb08698170153ef7db672c497c1840dcc8613ce26a8a005/fsspec-0.8.4-py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 13.5MB/s
# Collecting future>=0.17.1
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#      |████████████████████████████████| 829kB 58.3MB/s
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.6/dist-packages (from pytorch-lightning==1.0.8) (4.41.1)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.6/dist-packages (from pytorch-lightning==1.0.8) (1.18.5)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from pytorch-lightning==1.0.8) (2.3.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.3->pytorch-lightning==1.0.8) (3.7.4.3)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.3->pytorch-lightning==1.0.8) (0.8)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.8) (0.4.2)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.8) (0.36.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.8) (1.34.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.8) (0.10.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.8) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.8) (1.7.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.8) (3.3.3)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.8) (3.12.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.8) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.8) (50.3.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.8) (1.15.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.8) (1.17.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.0.8) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning==1.0.8) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning==1.0.8) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning==1.0.8) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning==1.0.8) (3.0.4)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning==1.0.8) (3.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.0.8) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.0.8) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.0.8) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.0.8) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning==1.0.8) (3.4.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.0.8) (0.4.8)
# Building wheels for collected packages: PyYAML, future
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44620 sha256=c50e1d33daa30d4658368da541beb8ed325bb0a57d9fa5ab4a520570d84a2915
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-cp36-none-any.whl size=491057 sha256=d4db56fe19f59395fef6cf3482f74ad08258426b0ba7f6fe4242d6bfdca48790
#   Stored in directory: /root/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built PyYAML future
# Installing collected packages: PyYAML, fsspec, future, pytorch-lightning
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# Successfully installed PyYAML-5.3.1 fsspec-0.8.4 future-0.18.2 pytorch-lightning-1.0.8

# %%
import numpy as np
import pandas as pd
import torch

from read_data import *
from FinSentiment import *

if torch.cuda.is_available():
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4

# %% [markdown]
# # Train Models

# %% [markdown]
# ### Train on Correct

# %%
pretrained_bert_name = 'distilbert-base-cased'
incorrect_type = 'correct'
company_embedding_method = 'concat'
company_weight = 2
burn_in_epochs = 2
max_epochs = burn_in_epochs + 4
existing_company_only = False

model_name = '_'.join([pretrained_bert_name, incorrect_type, company_embedding_method]) + '_full_data'

#############################################################################################
tokenizer = DistilBertTokenizer.from_pretrained(pretrained_bert_name)
(train_ids,X_train,y_train), (val_ids,X_val,y_val), (test_ids,X_test,y_test), _ = read_data(incorrect_type, dir_path='data/', existing_company_only=existing_company_only, sample=None)

X_train = np.concatenate([X_train, X_val])
y_train = np.concatenate([y_train, y_val])
train_ids = np.concatenate([train_ids, val_ids])

train_dataloader = tokenize_and_dataloader(X_train, y_train, tokenizer, train_ids, 16, 4, random=True)
val_dataloader = tokenize_and_dataloader(X_test, y_test, tokenizer, test_ids, 16, 4, random=False)

#############################################################################################
model = FinSentiment(pretrained_bert_name, incorrect_type, company_embedding_method, company_weight, 
                     lr=5e-5, hidden_dropout_prob=0.1, discriminate=True, burn_in_epochs=burn_in_epochs)

logger = TensorBoardLogger('experiments/logs', name=model_name)
checkpoint_callback = ModelCheckpoint(
    filepath = 'experiments/saved_models/' + company_embedding_method + '/' + model_name + '/' + model_name,
    monitor='val_loss',
    mode='min',
    save_top_k=1,
    save_last=True,
    verbose=False
)
trainer = pl.Trainer(progress_bar_refresh_rate=20, gpus=1, max_epochs=max_epochs, logger=logger, callbacks=[checkpoint_callback], fast_dev_run=False)
trainer.fit(model, train_dataloader, val_dataloader)

trainer.save_checkpoint('experiments/saved_models/' + company_embedding_method + '/' + model_name + '/' + model_name + '_last.ckpt')
# Out:
# [PROGRESS] Saving hyperparameters
# [PROGRESS] Initializing BERT model
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=411.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=263273408.0, style=ProgressStyle(descri…
# [PROGRESS] Initializing Company Embedding Layer
# [PROGRESS] Initializing classifier
# [PROGRESS] Done initialization
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type            | Params
# --------------------------------------------------
# 0 | bert          | DistilBertModel | 65.2 M
# 1 | company_layer | Embedding       | 808 K
# 2 | classifier    | Sequential      | 2.4 M
# 3 | pooler        | BertPooler      | 590 K
# 4 | dropout       | Dropout         | 0
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (3) and target (4) number of classes
#   warnings.warn(*args, **kwargs)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# [PROGRESS] Burning in classifier epoch 0
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# [PROGRESS] Burning in classifier epoch 1
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Saving latest checkpoint...

# %%
evaluate_model(model, tokenizer, trainer, existing_company_only=False, dir_path='data/',batch_size=16, num_workers=4)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (14) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_correct_concat 	 [INCORRECT TYPE]: correct
# RESULTS:
# 	Accuracy: 		0.9517
# 	Weighted Accuracy: 	0.9569
# 	F1 Score: 		0.9517
# 	AUC_SCORE[CLS 0]: 	0.9984
# 	AUC_SCORE[CLS 1]: 	0.9929
# 	AUC_SCORE[CLS 2]: 	0.9603
# 	AUC_SCORE[CLS 3]: 	0.9829
# 	AUC_SCORE[CLS 4]: 	0.9985
#
# Confusion Matrix
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_correct_concat 	 [INCORRECT TYPE]: inverse
# RESULTS:
# 	Accuracy: 		0.8493
# 	Weighted Accuracy: 	0.8054
# 	F1 Score: 		0.8493
# 	AUC_SCORE[CLS 0]: 	0.8365
# 	AUC_SCORE[CLS 1]: 	0.8060
# 	AUC_SCORE[CLS 2]: 	0.9573
# 	AUC_SCORE[CLS 3]: 	0.8977
# 	AUC_SCORE[CLS 4]: 	0.9234
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (14) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_correct_concat 	 [INCORRECT TYPE]: boundary
# 	Boundary Accuracy: 		0.8522
# 	Drop Total Sample: 		884.0000
# --------------------------------------------------------------------------------

# %%
evaluate_model(model, tokenizer, trainer, existing_company_only=True, dir_path='data/',batch_size=16, num_workers=4)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_correct_concat 	 [INCORRECT TYPE]: correct
# RESULTS:
# 	Accuracy: 		0.9503
# 	Weighted Accuracy: 	0.9552
# 	F1 Score: 		0.9503
# 	AUC_SCORE[CLS 0]: 	0.9975
# 	AUC_SCORE[CLS 1]: 	0.9929
# 	AUC_SCORE[CLS 2]: 	0.9559
# 	AUC_SCORE[CLS 3]: 	0.9829
# 	AUC_SCORE[CLS 4]: 	0.9990
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (14) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_correct_concat 	 [INCORRECT TYPE]: inverse
# RESULTS:
# 	Accuracy: 		0.8407
# 	Weighted Accuracy: 	0.7934
# 	F1 Score: 		0.8407
# 	AUC_SCORE[CLS 0]: 	0.8413
# 	AUC_SCORE[CLS 1]: 	0.7897
# 	AUC_SCORE[CLS 2]: 	0.9535
# 	AUC_SCORE[CLS 3]: 	0.8945
# 	AUC_SCORE[CLS 4]: 	0.9172
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (14) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_correct_concat 	 [INCORRECT TYPE]: boundary
# 	Boundary Accuracy: 		0.8405
# 	Drop Total Sample: 		519.0000
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Train on Inverse

# %%
pretrained_bert_name = 'distilbert-base-cased'
incorrect_type = 'inverse'
company_embedding_method = 'concat'
company_weight = 2
burn_in_epochs = 2
max_epochs = burn_in_epochs + 4
existing_company_only = False

model_name = '_'.join([pretrained_bert_name, incorrect_type, company_embedding_method]) + '_full_data'

#############################################################################################
tokenizer = DistilBertTokenizer.from_pretrained(pretrained_bert_name)
(train_ids,X_train,y_train), (val_ids,X_val,y_val), (test_ids,X_test,y_test), _ = read_data(incorrect_type, dir_path='data/', existing_company_only=existing_company_only, sample=None)

X_train = np.concatenate([X_train, X_val])
y_train = np.concatenate([y_train, y_val])
train_ids = np.concatenate([train_ids, val_ids])

train_dataloader = tokenize_and_dataloader(X_train, y_train, tokenizer, train_ids, 16, 4, random=True)
val_dataloader = tokenize_and_dataloader(X_test, y_test, tokenizer, test_ids, 16, 4, random=False)

#############################################################################################
model = FinSentiment(pretrained_bert_name, incorrect_type, company_embedding_method, company_weight, 
                     lr=5e-5, hidden_dropout_prob=0.1, discriminate=True, burn_in_epochs=burn_in_epochs)

logger = TensorBoardLogger('experiments/logs', name=model_name)
checkpoint_callback = ModelCheckpoint(
    filepath = 'experiments/saved_models/' + company_embedding_method + '/' + model_name + '/' + model_name,
    monitor='val_loss',
    mode='min',
    save_top_k=1,
    save_last=True,
    verbose=False
)
trainer = pl.Trainer(progress_bar_refresh_rate=20, gpus=1, max_epochs=max_epochs, logger=logger, callbacks=[checkpoint_callback], fast_dev_run=False)
trainer.fit(model, train_dataloader, val_dataloader)

trainer.save_checkpoint('experiments/saved_models/' + company_embedding_method + '/' + model_name + '/' + model_name + '_last.ckpt')
# Out:
# [PROGRESS] Saving hyperparameters
# [PROGRESS] Initializing BERT model
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [PROGRESS] Initializing Company Embedding Layer
# [PROGRESS] Initializing classifier
# [PROGRESS] Done initialization
#   | Name          | Type            | Params
# --------------------------------------------------
# 0 | bert          | DistilBertModel | 65.2 M
# 1 | company_layer | Embedding       | 808 K
# 2 | classifier    | Sequential      | 2.4 M
# 3 | pooler        | BertPooler      | 590 K
# 4 | dropout       | Dropout         | 0
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (4) and target (4) number of classes
#   warnings.warn(*args, **kwargs)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# [PROGRESS] Burning in classifier epoch 0
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# [PROGRESS] Burning in classifier epoch 1
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Saving latest checkpoint...

# %%
evaluate_model(model, tokenizer, trainer, existing_company_only=False, dir_path='data/',batch_size=16, num_workers=4)

# %%
evaluate_model(model, tokenizer, trainer, existing_company_only=True, dir_path='data/',batch_size=16, num_workers=4)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_inverse_concat 	 [INCORRECT TYPE]: correct
# RESULTS:
# 	Accuracy: 		0.9291
# 	Weighted Accuracy: 	0.9480
# 	F1 Score: 		0.9291
# 	AUC_SCORE[CLS 0]: 	0.9963
# 	AUC_SCORE[CLS 1]: 	0.9701
# 	AUC_SCORE[CLS 2]: 	0.9660
# 	AUC_SCORE[CLS 3]: 	0.9773
# 	AUC_SCORE[CLS 4]: 	0.9985
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (10) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_inverse_concat 	 [INCORRECT TYPE]: inverse
# RESULTS:
# 	Accuracy: 		0.9024
# 	Weighted Accuracy: 	0.9102
# 	F1 Score: 		0.9024
# 	AUC_SCORE[CLS 0]: 	0.9932
# 	AUC_SCORE[CLS 1]: 	0.9602
# 	AUC_SCORE[CLS 2]: 	0.9702
# 	AUC_SCORE[CLS 3]: 	0.9639
# 	AUC_SCORE[CLS 4]: 	0.9966
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (10) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_inverse_concat 	 [INCORRECT TYPE]: boundary
# 	Boundary Accuracy: 		0.9093
# 	Drop Total Sample: 		581.0000
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Train on Boundary

# %%
pretrained_bert_name = 'distilbert-base-cased'
incorrect_type = 'boundary'
company_embedding_method = 'concat'
company_weight = 2
burn_in_epochs = 2
max_epochs = burn_in_epochs + 4
existing_company_only = False

model_name = '_'.join([pretrained_bert_name, incorrect_type, company_embedding_method]) + '_full_data'

#############################################################################################
tokenizer = DistilBertTokenizer.from_pretrained(pretrained_bert_name)
(train_ids,X_train,y_train), (val_ids,X_val,y_val), (test_ids,X_test,y_test), _ = read_data(incorrect_type, dir_path='data/', existing_company_only=existing_company_only, sample=None)

X_train = np.concatenate([X_train, X_val])
y_train = np.concatenate([y_train, y_val])
train_ids = np.concatenate([train_ids, val_ids])

train_dataloader = tokenize_and_dataloader(X_train, y_train, tokenizer, train_ids, 16, 4, random=True)
val_dataloader = tokenize_and_dataloader(X_test, y_test, tokenizer, test_ids, 16, 4, random=False)

#############################################################################################
model = FinSentiment(pretrained_bert_name, incorrect_type, company_embedding_method, company_weight, 
                     lr=5e-5, hidden_dropout_prob=0.1, discriminate=True, burn_in_epochs=burn_in_epochs)

logger = TensorBoardLogger('experiments/logs', name=model_name)
checkpoint_callback = ModelCheckpoint(
    filepath = 'experiments/saved_models/' + company_embedding_method + '/' + model_name + '/' + model_name,
    monitor='val_loss',
    mode='min',
    save_top_k=1,
    save_last=True,
    verbose=False
)
trainer = pl.Trainer(progress_bar_refresh_rate=20, gpus=1, max_epochs=max_epochs, logger=logger, callbacks=[checkpoint_callback], fast_dev_run=False)
trainer.fit(model, train_dataloader, val_dataloader)

trainer.save_checkpoint('experiments/saved_models/' + company_embedding_method + '/' + model_name + '/' + model_name + '_last.ckpt')

# %%
evaluate_model(model, tokenizer, trainer, existing_company_only=False, dir_path='data/',batch_size=16, num_workers=4)

# %%
evaluate_model(model, tokenizer, trainer, existing_company_only=True, dir_path='data/',batch_size=16, num_workers=4)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: correct
# RESULTS:
# 	Accuracy: 		0.9417
# 	Weighted Accuracy: 	0.9424
# 	F1 Score: 		0.9417
# 	AUC_SCORE[CLS 0]: 	0.9947
# 	AUC_SCORE[CLS 1]: 	0.9897
# 	AUC_SCORE[CLS 2]: 	0.9811
# 	AUC_SCORE[CLS 3]: 	0.9877
# 	AUC_SCORE[CLS 4]: 	0.9965
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: inverse
# RESULTS:
# 	Accuracy: 		0.8618
# 	Weighted Accuracy: 	0.8505
# 	F1 Score: 		0.8618
# 	AUC_SCORE[CLS 0]: 	0.9616
# 	AUC_SCORE[CLS 1]: 	0.9772
# 	AUC_SCORE[CLS 2]: 	0.9827
# 	AUC_SCORE[CLS 3]: 	0.9775
# 	AUC_SCORE[CLS 4]: 	0.9839
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: boundary
# 	Boundary Accuracy: 		0.9638
# 	Drop Total Sample: 		338.0000
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: correct
# RESULTS:
# 	Accuracy: 		0.9417
# 	Weighted Accuracy: 	0.9424
# 	F1 Score: 		0.9417
# 	AUC_SCORE[CLS 0]: 	0.9947
# 	AUC_SCORE[CLS 1]: 	0.9897
# 	AUC_SCORE[CLS 2]: 	0.9811
# 	AUC_SCORE[CLS 3]: 	0.9877
# 	AUC_SCORE[CLS 4]: 	0.9965
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: inverse
# RESULTS:
# 	Accuracy: 		0.8618
# 	Weighted Accuracy: 	0.8505
# 	F1 Score: 		0.8618
# 	AUC_SCORE[CLS 0]: 	0.9616
# 	AUC_SCORE[CLS 1]: 	0.9772
# 	AUC_SCORE[CLS 2]: 	0.9827
# 	AUC_SCORE[CLS 3]: 	0.9775
# 	AUC_SCORE[CLS 4]: 	0.9839
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: boundary
# 	Boundary Accuracy: 		0.9638
# 	Drop Total Sample: 		338.0000
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: correct
# RESULTS:
# 	Accuracy: 		0.9417
# 	Weighted Accuracy: 	0.9424
# 	F1 Score: 		0.9417
# 	AUC_SCORE[CLS 0]: 	0.9947
# 	AUC_SCORE[CLS 1]: 	0.9897
# 	AUC_SCORE[CLS 2]: 	0.9811
# 	AUC_SCORE[CLS 3]: 	0.9877
# 	AUC_SCORE[CLS 4]: 	0.9965
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: inverse
# RESULTS:
# 	Accuracy: 		0.8618
# 	Weighted Accuracy: 	0.8505
# 	F1 Score: 		0.8618
# 	AUC_SCORE[CLS 0]: 	0.9616
# 	AUC_SCORE[CLS 1]: 	0.9772
# 	AUC_SCORE[CLS 2]: 	0.9827
# 	AUC_SCORE[CLS 3]: 	0.9775
# 	AUC_SCORE[CLS 4]: 	0.9839
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: boundary
# 	Boundary Accuracy: 		0.9638
# 	Drop Total Sample: 		338.0000
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: correct
# RESULTS:
# 	Accuracy: 		0.9417
# 	Weighted Accuracy: 	0.9424
# 	F1 Score: 		0.9417
# 	AUC_SCORE[CLS 0]: 	0.9947
# 	AUC_SCORE[CLS 1]: 	0.9897
# 	AUC_SCORE[CLS 2]: 	0.9811
# 	AUC_SCORE[CLS 3]: 	0.9877
# 	AUC_SCORE[CLS 4]: 	0.9965
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: inverse
# RESULTS:
# 	Accuracy: 		0.8618
# 	Weighted Accuracy: 	0.8505
# 	F1 Score: 		0.8618
# 	AUC_SCORE[CLS 0]: 	0.9616
# 	AUC_SCORE[CLS 1]: 	0.9772
# 	AUC_SCORE[CLS 2]: 	0.9827
# 	AUC_SCORE[CLS 3]: 	0.9775
# 	AUC_SCORE[CLS 4]: 	0.9839
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: boundary
# 	Boundary Accuracy: 		0.9638
# 	Drop Total Sample: 		338.0000
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: correct
# RESULTS:
# 	Accuracy: 		0.9417
# 	Weighted Accuracy: 	0.9424
# 	F1 Score: 		0.9417
# 	AUC_SCORE[CLS 0]: 	0.9947
# 	AUC_SCORE[CLS 1]: 	0.9897
# 	AUC_SCORE[CLS 2]: 	0.9811
# 	AUC_SCORE[CLS 3]: 	0.9877
# 	AUC_SCORE[CLS 4]: 	0.9965
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: inverse
# RESULTS:
# 	Accuracy: 		0.8618
# 	Weighted Accuracy: 	0.8505
# 	F1 Score: 		0.8618
# 	AUC_SCORE[CLS 0]: 	0.9616
# 	AUC_SCORE[CLS 1]: 	0.9772
# 	AUC_SCORE[CLS 2]: 	0.9827
# 	AUC_SCORE[CLS 3]: 	0.9775
# 	AUC_SCORE[CLS 4]: 	0.9839
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: boundary
# 	Boundary Accuracy: 		0.9638
# 	Drop Total Sample: 		338.0000
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: correct
# RESULTS:
# 	Accuracy: 		0.9417
# 	Weighted Accuracy: 	0.9424
# 	F1 Score: 		0.9417
# 	AUC_SCORE[CLS 0]: 	0.9947
# 	AUC_SCORE[CLS 1]: 	0.9897
# 	AUC_SCORE[CLS 2]: 	0.9811
# 	AUC_SCORE[CLS 3]: 	0.9877
# 	AUC_SCORE[CLS 4]: 	0.9965
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: inverse
# RESULTS:
# 	Accuracy: 		0.8618
# 	Weighted Accuracy: 	0.8505
# 	F1 Score: 		0.8618
# 	AUC_SCORE[CLS 0]: 	0.9616
# 	AUC_SCORE[CLS 1]: 	0.9772
# 	AUC_SCORE[CLS 2]: 	0.9827
# 	AUC_SCORE[CLS 3]: 	0.9775
# 	AUC_SCORE[CLS 4]: 	0.9839
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: boundary
# 	Boundary Accuracy: 		0.9638
# 	Drop Total Sample: 		338.0000
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: correct
# RESULTS:
# 	Accuracy: 		0.9417
# 	Weighted Accuracy: 	0.9424
# 	F1 Score: 		0.9417
# 	AUC_SCORE[CLS 0]: 	0.9947
# 	AUC_SCORE[CLS 1]: 	0.9897
# 	AUC_SCORE[CLS 2]: 	0.9811
# 	AUC_SCORE[CLS 3]: 	0.9877
# 	AUC_SCORE[CLS 4]: 	0.9965
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: inverse
# RESULTS:
# 	Accuracy: 		0.8618
# 	Weighted Accuracy: 	0.8505
# 	F1 Score: 		0.8618
# 	AUC_SCORE[CLS 0]: 	0.9616
# 	AUC_SCORE[CLS 1]: 	0.9772
# 	AUC_SCORE[CLS 2]: 	0.9827
# 	AUC_SCORE[CLS 3]: 	0.9775
# 	AUC_SCORE[CLS 4]: 	0.9839
#
# Confusion Matrix
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:45: RuntimeWarning: You have set 5 number of classes which is different from predicted (11) and target (5) number of classes
#   warnings.warn(*args, **kwargs)
# ====================================================================================================
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ====================================================================================================
# [MODEL NAME]: distilbert-base-cased_boundary_concat 	 [INCORRECT TYPE]: boundary
# 	Boundary Accuracy: 		0.9638
# 	Drop Total Sample: 		338.0000
# --------------------------------------------------------------------------------

# %% [markdown]
# # Check Best Models

# %%
pretrained_bert_name = 'distilbert-base-cased'
company_embedding_method = 'concat'

tokenizer = DistilBertTokenizer.from_pretrained(pretrained_bert_name)
trainer = pl.Trainer(progress_bar_refresh_rate=20, gpus=1)

# %%
incorrect_type = 'correct'
model_name = '_'.join([pretrained_bert_name, incorrect_type, company_embedding_method])
filepath = 'experiments/saved_models/' + company_embedding_method + '/' + model_name + '/' + model_name + '-v0.ckpt'
model = FinSentiment.load_from_checkpoint(filepath)
evaluate_model(model, tokenizer, trainer, existing_company_only=True, dir_path='data/',batch_size=16, num_workers=4)

# %%
incorrect_type = 'inverse'
model_name = '_'.join([pretrained_bert_name, incorrect_type, company_embedding_method])
filepath = 'experiments/saved_models/' + company_embedding_method + '/' + model_name + '/' + model_name + '-v0.ckpt'
model = FinSentiment.load_from_checkpoint(filepath)
evaluate_model(model, tokenizer, trainer, existing_company_only=True, dir_path='data/',batch_size=16, num_workers=4)

# %%
incorrect_type = 'boundary'
model_name = '_'.join([pretrained_bert_name, incorrect_type, company_embedding_method])
filepath = 'experiments/saved_models/' + company_embedding_method + '/' + model_name + '/' + model_name + '-v0.ckpt'
model = FinSentiment.load_from_checkpoint(filepath)
evaluate_model(model, tokenizer, trainer, existing_company_only=True, dir_path='data/',batch_size=16, num_workers=4)

# %%
# %load_ext tensorboard
# %tensorboard --logdir experiments/logs/
